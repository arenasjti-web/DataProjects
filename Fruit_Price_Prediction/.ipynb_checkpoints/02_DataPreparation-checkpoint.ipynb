# %% [markdown]
# # Preparación e Integración de Datos
#
# ## Objetivo
#
# Este notebook realiza el proceso completo de limpieza, transformación e integración de los datasets utilizados para el análisis y modelado predictivo de precios agrícolas.
#
# El resultado final es un único conjunto de datos consistente, listo para ser utilizado en análisis exploratorio, entrenamiento de modelos y visualización.
#
# ---
#
# ## Flujo del proceso
#
# 1. Carga de los datos agrícolas provenientes de múltiples archivos anuales.
# 2. Limpieza y estandarización de variables.
# 3. Corrección de valores faltantes mediante reglas derivadas de la estructura de los datos.
# 4. Consolidación de todos los años en un único DataFrame.
# 5. Carga y procesamiento de los datos meteorológicos diarios.
# 6. Agregación de información meteorológica a frecuencia semanal.
# 7. Integración de ambas fuentes mediante región, año y semana ISO.
# 8. Exportación del dataset final.
#
# ## Diccionario de datos:
#
# | Variable | Tipo | Descripción |
# |----------|------|-------------|
# | **semana** | Entero | Número de semana del año (calendario ISO) correspondiente al período de observación. |
# | **fecha_inicio** | Fecha | Fecha de inicio de la semana de monitoreo. |
# | **fecha_termino** | Fecha | Fecha de término de la semana de monitoreo. |
# | **region** | Categórica | Región de Chile donde se realizó el monitoreo de precios. |
# | **tipo_punto_monitoreo** | Categórica | Tipo de establecimiento donde se registró el precio (por ejemplo: feria libre, supermercado, mercado mayorista, entre otros). |
# | **producto** | Categórica | Nombre del producto agrícola monitoreado. |
# | **variedad** | Categórica | Variedad específica del producto, cuando corresponde. |
# | **calidad** | Categórica | Clasificación de calidad informada para el producto. |
# | **unidad** | Categórica | Unidad de medida utilizada para registrar el precio (kg, unidad, bandeja, etc.). |
# | **precio_minimo** | Numérica | Precio mínimo observado durante la semana para el producto. |
# | **precio_maximo** | Numérica | Precio máximo observado durante la semana para el producto. |
# | **precio_promedio** | Numérica | Precio promedio observado durante la semana para el producto. |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#
from src.preprocessing import formatCategorical, formatColNames

# %% [markdown]
# # Data Agrícola
#
# ## Preparación de los datos agrícolas
#
# Los datos originales provienen de múltiples archivos obtenidos mediante consultas al sistema de la oficina de estudios y políticas agrarias(ODEPA). Los archivos presentan formatos con columnas auxiliares generadas por Excel y valores faltantes en algunas variables categóricas que deben ser corregidas.
#
# En esta sección se realiza la limpieza y normalización necesaria para obtener un único dataset homogéneo.

# %%
#Los archivos no son limpios por lo que dará un warning sobre su formato.
#Aspectos estéticos del archivo hacen que el nombre de columnas se obtenda de la fila 4
df_by_year = {
       '20-21':  pd.read_excel(
            "./Data/precio-consumidor_semanal_202001-202151.xlsx",
            header=4
        ),
        '21-22':  pd.read_excel(
            "./Data/precio-consumidor_semanal_202152-202252.xlsx",
            header=4
        ),
        '23-24': pd.read_excel(
            "./Data/precio-consumidor_semanal_202301-202401.xlsx",
            header=4
        ),
        '24-25': pd.read_excel(
            "./Data/precio-consumidor_semanal_202402-202501.xlsx",
            header=4
        ),
        '25-26':pd.read_excel(
            "./Data/precio-consumidor_semanal_202502-202627.xlsx",
            header=4
        )
}
# Out:
# C:\Users\Joaquin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Joaquin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Joaquin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Joaquin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Joaquin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_by_year['20-21'].head()
# Out:
#   semana fecha_inicio                        region tipo_punto_monitoreo  \
# 0      1   30-12-2019  región_de_arica_y_parinacota    mercado_minorista
# 1      1   30-12-2019  región_de_arica_y_parinacota    mercado_minorista
# 2      1   30-12-2019  región_de_arica_y_parinacota    mercado_minorista
# 3      1   30-12-2019  región_de_arica_y_parinacota    mercado_minorista
# 4      1   30-12-2019  región_de_arica_y_parinacota    mercado_minorista
#
#                     producto variedad calidad  unidad  precio_minimo  \
# 0    aceituna_amarga_(extra)      NaN     NaN  $/kilo         3500.0
# 1  aceituna_amarga_(primera)      NaN     NaN  $/kilo         3000.0
# 2  aceituna_amarga_(segunda)      NaN     NaN  $/kilo         2500.0
# 3  aceituna_amarga_(tercera)      NaN     NaN  $/kilo         2000.0
# 4     aceituna_negra_(extra)      NaN     NaN  $/kilo         3000.0
#
#    precio_maximo  precio_promedio
# 0         4000.0           3750.0
# 1         3500.0           3250.0
# 2         3000.0           2750.0
# 3         2500.0           2250.0
# 4         3500.0           3250.0

# %%
categorical_cols = list(df_by_year['20-21'].dtypes[df_by_year['20-21'].dtypes == 'str'].index) # usamos el primer dataframe como marco de referencia
categorical_cols
# Out:
# ['Fecha inicio',
#  'Fecha término',
#  'Región',
#  'Tipo punto monitoreo',
#  'Producto',
#  'Variedad',
#  'Calidad',
#  'Unidad']

# %%
#Semana y fecha término son dispensables. seguiremos solo con fecha inicio
categorical_cols.remove("Fecha término")

# %% [markdown]
# ### Limpieza y estandarización
#
# Las principales transformaciones realizadas son:
#
# - eliminación de columnas vacías o auxiliares;
# - normalización de nombres de columnas;
# - estandarización de variables categóricas;
# - conversión de fechas;
# - eliminación de registros incompletos cuando corresponde.

# %%
def cleanSheets(df):

    #Eliminar columnas estéticos o sobrantes
    df = df.dropna(axis=1, how="all") #los archivos poseen con una columna vacia "unnamed". hay que borrarla
    df = df.drop(columns=[ "Fecha término"])
    #Eliminar última fila
    df = df.iloc[:-1]# Esta fila solo contiene un informativo sobre la fuente de los datos. no es parte de la tabla.
    return df

# %%
for year, df in df_by_year.items():
    df_by_year[year] = cleanSheets(df)
    formatCategorical(df_by_year[year], categorical_cols)
    formatColNames(df_by_year[year])

# %% [markdown]
# ### Consolidación histórica
#
# Una vez limpiados todos los archivos anuales, se consolidan en un único DataFrame que contiene toda la información histórica disponible.

# %%
df_agricola = pd.concat(df_by_year.values(), ignore_index=True)

# %%
df_agricola
# Out:
#        semana fecha_inicio                            region  \
# 0           1   30-12-2019      región_de_arica_y_parinacota
# 1           1   30-12-2019      región_de_arica_y_parinacota
# 2           1   30-12-2019      región_de_arica_y_parinacota
# 3           1   30-12-2019      región_de_arica_y_parinacota
# 4           1   30-12-2019      región_de_arica_y_parinacota
# ...       ...          ...                               ...
# 159259     27   29-06-2026  región_metropolitana_de_santiago
# 159260     27   29-06-2026  región_metropolitana_de_santiago
# 159261     27   29-06-2026  región_metropolitana_de_santiago
# 159262     27   29-06-2026  región_metropolitana_de_santiago
# 159263     27   29-06-2026  región_metropolitana_de_santiago
#
#          tipo_punto_monitoreo                   producto           variedad  \
# 0           mercado_minorista    aceituna_amarga_(extra)                NaN
# 1           mercado_minorista  aceituna_amarga_(primera)                NaN
# 2           mercado_minorista  aceituna_amarga_(segunda)                NaN
# 3           mercado_minorista  aceituna_amarga_(tercera)                NaN
# 4           mercado_minorista     aceituna_negra_(extra)                NaN
# ...                       ...                        ...                ...
# 159259  supermercado_en_línea                      mango    sin_especificar
# 159260  supermercado_en_línea                    manzana       granny_smith
# 159261  supermercado_en_línea                      palta               hass
# 159262  supermercado_en_línea                       pera  packham's_triumph
# 159263  supermercado_en_línea                    plátano    sin_especificar
#
#         calidad  unidad  precio_minimo  precio_maximo  precio_promedio
# 0           NaN  $/kilo         3500.0         4000.0           3750.0
# 1           NaN  $/kilo         3000.0         3500.0           3250.0
# 2           NaN  $/kilo         2500.0         3000.0           2750.0
# 3           NaN  $/kilo         2000.0         2500.0           2250.0
# 4           NaN  $/kilo         3000.0         3500.0           3250.0
# ...         ...     ...            ...            ...              ...
# 159259  primera  $/kilo         2990.0         3010.0           2997.0
# 159260  primera  $/kilo         1990.0         2590.0           2415.0
# 159261  primera  $/kilo         6290.0         6490.0           6423.0
# 159262  primera  $/kilo         2150.0         2190.0           2177.0
# 159263  primera  $/kilo         1450.0         1590.0           1520.0
#
# [159264 rows x 11 columns]

# %% [markdown]
# ### Preparacion previa al futuro Merge con la data meteorológica
#
#     -Convertir a fecha el campo string **fecha_inicio**
#     -crear el campo **anio** usando isocalendar ( de esta manera la primera semana de 2020, la cual parte el 2019; marcará 2020 como año)
#     -Ya que tenemos semana y anio, se creará el campo **mes**. Esta podrá ser eliminada luego si se determina dispensable.

# %%
df_agricola["fecha_inicio"] = pd.to_datetime(df_agricola["fecha_inicio"])

iso = df_agricola["fecha_inicio"].dt.isocalendar() # necesito usar ISO por que los datos agrícolas están por semana en este formato.
#ej: 1ra semana de 2020 parte del 30 de diciembre de 2019.

df_agricola["anio"] = iso.year
df_agricola["mes"] = df_agricola["fecha_inicio"].dt.month # Iso no tiene month al parecer..
# Out:
# C:\Users\Joaquin\AppData\Local\Temp\ipykernel_24764\1225151285.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_agricola["fecha_inicio"] = pd.to_datetime(df_agricola["fecha_inicio"])

# %%
   df_agricola
# Out:
#        semana fecha_inicio                            region  \
# 0           1   2019-12-30      región_de_arica_y_parinacota
# 1           1   2019-12-30      región_de_arica_y_parinacota
# 2           1   2019-12-30      región_de_arica_y_parinacota
# 3           1   2019-12-30      región_de_arica_y_parinacota
# 4           1   2019-12-30      región_de_arica_y_parinacota
# ...       ...          ...                               ...
# 159259     27   2026-06-29  región_metropolitana_de_santiago
# 159260     27   2026-06-29  región_metropolitana_de_santiago
# 159261     27   2026-06-29  región_metropolitana_de_santiago
# 159262     27   2026-06-29  región_metropolitana_de_santiago
# 159263     27   2026-06-29  región_metropolitana_de_santiago
#
#          tipo_punto_monitoreo                   producto           variedad  \
# 0           mercado_minorista    aceituna_amarga_(extra)                NaN
# 1           mercado_minorista  aceituna_amarga_(primera)                NaN
# 2           mercado_minorista  aceituna_amarga_(segunda)                NaN
# 3           mercado_minorista  aceituna_amarga_(tercera)                NaN
# 4           mercado_minorista     aceituna_negra_(extra)                NaN
# ...                       ...                        ...                ...
# 159259  supermercado_en_línea                      mango    sin_especificar
# 159260  supermercado_en_línea                    manzana       granny_smith
# 159261  supermercado_en_línea                      palta               hass
# 159262  supermercado_en_línea                       pera  packham's_triumph
# 159263  supermercado_en_línea                    plátano    sin_especificar
#
#         calidad  unidad  precio_minimo  precio_maximo  precio_promedio  anio  \
# 0           NaN  $/kilo         3500.0         4000.0           3750.0  2020
# 1           NaN  $/kilo         3000.0         3500.0           3250.0  2020
# 2           NaN  $/kilo         2500.0         3000.0           2750.0  2020
# 3           NaN  $/kilo         2000.0         2500.0           2250.0  2020
# 4           NaN  $/kilo         3000.0         3500.0           3250.0  2020
# ...         ...     ...            ...            ...              ...   ...
# 159259  primera  $/kilo         2990.0         3010.0           2997.0  2026
# 159260  primera  $/kilo         1990.0         2590.0           2415.0  2026
# 159261  primera  $/kilo         6290.0         6490.0           6423.0  2026
# 159262  primera  $/kilo         2150.0         2190.0           2177.0  2026
# 159263  primera  $/kilo         1450.0         1590.0           1520.0  2026
#
#         mes
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
# ...     ...
# 159259    6
# 159260    6
# 159261    6
# 159262    6
# 159263    6
#
# [159264 rows x 13 columns]

# %%
df_agricola.isnull().sum()
# Out:
# semana                     0
# fecha_inicio               0
# region                     0
# tipo_punto_monitoreo       0
# producto                   0
# variedad                3442
# calidad                 3442
# unidad                     0
# precio_minimo              0
# precio_maximo              0
# precio_promedio            0
# anio                       0
# mes                        0
# dtype: int64

# %% [markdown]
# ### Tratamiento de valores faltantes
#
# Se detectó que algunos registros no contenían información en las variables **Variedad** y **Calidad**.
# Se revisarán todos los valores unicos presentes en los campos categóricos

# %%
#lo obtengo de nuevo ya estás se modificaron previamente
categorical_cols = list(df_agricola.dtypes[df_agricola.dtypes == 'str'].index)

for col in categorical_cols:
    print(col)
    print(df_agricola[col].unique())#valores unicos
    print(df_agricola[col].nunique())#conteo de valores unicos
    print()
# Out:
# region
# <StringArray>
# [    'región_de_arica_y_parinacota',               'región_de_coquimbo',
#            'región_de_la_araucanía',              'región_de_los_lagos',
#                   'región_de_ñuble',             'región_de_valparaíso',
#                 'región_del_biobío',                 'región_del_maule',
#  'región_metropolitana_de_santiago']
# Length: 9, dtype: str
# 9
#
# tipo_punto_monitoreo
# <StringArray>
# ['mercado_minorista', 'supermercado', 'feria_libre', 'supermercado_en_línea']
# Length: 4, dtype: str
# 4
#
# producto
# <StringArray>
# [     'aceituna_amarga_(extra)',    'aceituna_amarga_(primera)',
#     'aceituna_amarga_(segunda)',    'aceituna_amarga_(tercera)',
#        'aceituna_negra_(extra)',     'aceituna_negra_(primera)',
#      'aceituna_negra_(segunda)',     'aceituna_negra_(tercera)',
#    'aceituna_sevillana_(extra)', 'aceituna_sevillana_(primera)',
#  'aceituna_sevillana_(segunda)', 'aceituna_sevillana_(tercera)',
#                        'cereza',                      'durazno',
#                      'frutilla',                        'limón',
#                         'mango',                      'manzana',
#                       'naranja',                     'nectarín',
#                         'palta',                         'pera',
#                       'plátano',                    'chirimoya',
#               'arándano_(blue)',                      'ciruela',
#                     'frambuesa',                          'uva',
#                          'kiwi',                    'mandarina',
#                       'damasco',                         'tuna']
# Length: 32, dtype: str
# 32
#
# variedad
# <StringArray>
# [                 nan,             'lapins',            'rainier',
#         'springcrest',    'sin_especificar',         'fuji_royal',
#        'granny_smith',           'valencia',         'early_john',
#         'super_queen',               'hass',  'packham's_triumph',
#         'black_amber',             'carson',          'rich_lady',
#             'andross',       'elegant_lady',         'royal_gala',
#          'june_pearl',              'venus',     'flame_seedless',
#   'superior_seedless', 'bartlett_de_verano',          'larry_ann',
#        'doctor_davis',      'september_sun',       'artic_sprite',
#          'august_red',          'red_globe',  'thompson_seedless',
#      'phillips_cling',    'september_sweet',         'artic_snow',
#             'hayward',           'fukumoto',         'clementina',
#        'winter_nelis',        'clemenuless',         'navel_late',
#           'pink_lady',          'lane_late',            'murcott',
#              'brooks',       'castle_brite',       'florida_king',
#          'springtime',         'artic_star',          'early_glo',
#             'modesto',            'santina',       'flavor_crest',
#               'manon',        'royal_glory',       'nectar_crest',
#        'ruby_diamond',            'fortuna',           'angeleno',
#            'new_hall',       'early_burlat',            'edranol',
#         'sweet_heart',     'early_majestic',        'artic_pride',
#                'bing',       'super_august',         'valenciana',
#          'polar_king',                'van',      'spring_bright',
#            'sapphire',         'white_lady',         'artic_mist',
#         'red_diamond',         'conservero']
# Length: 74, dtype: str
# 73
#
# calidad
# <StringArray>
# [          nan,     'segunda',     'primera', '1a_plateado', '2a_amarillo',
#  '2a_plateado', '1a_amarillo']
# Length: 7, dtype: str
# 6
#
# unidad
# <StringArray>
# ['$/kilo']
# Length: 1, dtype: str
# 1

# %% [markdown]
# ### Los siguientes campos no presentan problemas:
#
# - Región,tipo_punto_monitoreo, unidad
#
# **Solo viene un tipo de unidad,"$/Kg"( esperable para este tipo de producto); por lo que es obviable el campo**
# ### Campos con problemas:
#
# - producto:
#     - Entradas en formato nombre_variedad, ej: arándano_(blue)
#     - Entradas en formato nombre_variedad_calidad, ej: aceituna_amarga_(extra)
# - variedad:
#     -  nan: esto deberia corregirse al tratar con el campo anterior
#     -  sin_especificar: esto deberia contar como nan y complica las cosas quedandose como está
# - calidad :
#     - '1a_plateado','2a_amarillo', '2a_plateado', '1a_amarillo' : 1a|2a deberia cambiarse por primera|segunda, lo demás corresponde a variedad
#     -  nan: esto deberia corregirse entre al tratar con producto como con el punto anterior.

# %%
df_agricola["variedad"] = df_agricola["variedad"].replace("sin_especificar", np.nan)

# %%
#nan aumento en más de 46 mil para variedad
df_agricola.isnull().sum()
# Out:
# semana                      0
# fecha_inicio                0
# region                      0
# tipo_punto_monitoreo        0
# producto                    0
# variedad                50837
# calidad                  3442
# unidad                      0
# precio_minimo               0
# precio_maximo               0
# precio_promedio             0
# anio                        0
# mes                         0
# dtype: int64

# %%
df_na = df_agricola[df_agricola['variedad'].isna()]

# %%
#ejemplo
df_na.iloc[1]["producto"].split("_")
# Out:
# ['aceituna', 'amarga', '(primera)']

# %%
#Obtener variedad y calidad a partir del nombre para los casos que haga falta

# %%
for row in df_agricola[df_agricola.variedad.isna()].itertuples():
    partes = row.producto.split("_")

    if len(partes) == 3:
        df_agricola.at[row.Index, "producto"] = partes[0]
        df_agricola.at[row.Index, "variedad"] = partes[1]
        df_agricola.at[row.Index, "calidad"] = partes[2]

    elif len(partes) == 2:
        df_agricola.at[row.Index, "producto"] = partes[0]
        df_agricola.at[row.Index, "variedad"] = partes[1]
        # calidad queda como está (NaN)

# %%
df_agricola.isnull().sum()
# Out:
# semana                      0
# fecha_inicio                0
# region                      0
# tipo_punto_monitoreo        0
# producto                    0
# variedad                44891
# calidad                     0
# unidad                      0
# precio_minimo               0
# precio_maximo               0
# precio_promedio             0
# anio                        0
# mes                         0
# dtype: int64

# %%
df_agricola.head()
# Out:
#   semana fecha_inicio                        region tipo_punto_monitoreo  \
# 0      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 1      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 2      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 3      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 4      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
#
#    producto variedad    calidad  unidad  precio_minimo  precio_maximo  \
# 0  aceituna   amarga    (extra)  $/kilo         3500.0         4000.0
# 1  aceituna   amarga  (primera)  $/kilo         3000.0         3500.0
# 2  aceituna   amarga  (segunda)  $/kilo         2500.0         3000.0
# 3  aceituna   amarga  (tercera)  $/kilo         2000.0         2500.0
# 4  aceituna    negra    (extra)  $/kilo         3000.0         3500.0
#
#    precio_promedio  anio  mes
# 0           3750.0  2020   12
# 1           3250.0  2020   12
# 2           2750.0  2020   12
# 3           2250.0  2020   12
# 4           3250.0  2020   12

# %%
#la columna calidad venia con los valores en parentesis luego del último proceso. hay que quitalos
df_agricola["calidad"] = df_agricola["calidad"].str.replace("(", "", regex=False)
df_agricola["calidad"] = df_agricola["calidad"].str.replace(")", "", regex=False)

df_agricola["producto"] = df_agricola["producto"].str.replace("(", "", regex=False)
df_agricola["producto"] = df_agricola["producto"].str.replace(")", "", regex=False)

df_agricola["variedad"] = df_agricola["variedad"].str.replace("(", "", regex=False)
df_agricola["variedad"] = df_agricola["variedad"].str.replace(")", "", regex=False)

df_agricola.head()
# Out:
#   semana fecha_inicio                        region tipo_punto_monitoreo  \
# 0      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 1      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 2      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 3      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 4      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
#
#    producto variedad  calidad  unidad  precio_minimo  precio_maximo  \
# 0  aceituna   amarga    extra  $/kilo         3500.0         4000.0
# 1  aceituna   amarga  primera  $/kilo         3000.0         3500.0
# 2  aceituna   amarga  segunda  $/kilo         2500.0         3000.0
# 3  aceituna   amarga  tercera  $/kilo         2000.0         2500.0
# 4  aceituna    negra    extra  $/kilo         3000.0         3500.0
#
#    precio_promedio  anio  mes
# 0           3750.0  2020   12
# 1           3250.0  2020   12
# 2           2750.0  2020   12
# 3           2250.0  2020   12
# 4           3250.0  2020   12

# %%
for col in categorical_cols:
    print(col)
    print(df_agricola[col].unique())#valores unicos
    print(df_agricola[col].nunique())#conteo de valores unicos
    print()
# Out:
# region
# <StringArray>
# [    'región_de_arica_y_parinacota',               'región_de_coquimbo',
#            'región_de_la_araucanía',              'región_de_los_lagos',
#                   'región_de_ñuble',             'región_de_valparaíso',
#                 'región_del_biobío',                 'región_del_maule',
#  'región_metropolitana_de_santiago']
# Length: 9, dtype: str
# 9
#
# tipo_punto_monitoreo
# <StringArray>
# ['mercado_minorista', 'supermercado', 'feria_libre', 'supermercado_en_línea']
# Length: 4, dtype: str
# 4
#
# producto
# <StringArray>
# [ 'aceituna',    'cereza',   'durazno',  'frutilla',     'limón',     'mango',
#    'manzana',   'naranja',  'nectarín',     'palta',      'pera',   'plátano',
#  'chirimoya',  'arándano',   'ciruela', 'frambuesa',       'uva',      'kiwi',
#  'mandarina',   'damasco',      'tuna']
# Length: 21, dtype: str
# 21
#
# variedad
# <StringArray>
# [            'amarga',              'negra',          'sevillana',
#              'lapins',            'rainier',        'springcrest',
#                   nan,         'fuji_royal',       'granny_smith',
#            'valencia',         'early_john',        'super_queen',
#                'hass',  'packham's_triumph',             '(blue)',
#         'black_amber',             'carson',          'rich_lady',
#             'andross',       'elegant_lady',         'royal_gala',
#          'june_pearl',              'venus',     'flame_seedless',
#   'superior_seedless', 'bartlett_de_verano',          'larry_ann',
#        'doctor_davis',      'september_sun',       'artic_sprite',
#          'august_red',          'red_globe',  'thompson_seedless',
#      'phillips_cling',    'september_sweet',         'artic_snow',
#             'hayward',           'fukumoto',         'clementina',
#        'winter_nelis',        'clemenuless',         'navel_late',
#           'pink_lady',          'lane_late',            'murcott',
#              'brooks',       'castle_brite',       'florida_king',
#          'springtime',         'artic_star',          'early_glo',
#             'modesto',            'santina',       'flavor_crest',
#               'manon',        'royal_glory',       'nectar_crest',
#        'ruby_diamond',            'fortuna',           'angeleno',
#            'new_hall',       'early_burlat',            'edranol',
#         'sweet_heart',     'early_majestic',        'artic_pride',
#                'bing',       'super_august',         'valenciana',
#          'polar_king',                'van',      'spring_bright',
#            'sapphire',         'white_lady',         'artic_mist',
#         'red_diamond',         'conservero']
# Length: 77, dtype: str
# 76
#
# calidad
# <StringArray>
# [      'extra',     'primera',     'segunda',     'tercera', '1a_plateado',
#  '2a_amarillo', '2a_plateado', '1a_amarillo']
# Length: 8, dtype: str
# 8
#
# unidad
# <StringArray>
# ['$/kilo']
# Length: 1, dtype: str
# 1

# %%
# necesito todas las entradas del campo calidad que contengan 1a o 2a y hacer un split...

for row in df_agricola[df_agricola["calidad"].str.contains("1a|2a", na=False)].itertuples():
    partes = row.calidad.split("_")
    
    if len(partes) == 2:    
        calidad = "primera" if partes[0] == "1a" else "segunda"
        df_agricola.at[row.Index, "variedad"] = partes[1]
        df_agricola.at[row.Index, "calidad"] = calidad

# %%
for col in categorical_cols:
    print(col)
    print(df_agricola[col].unique())#valores unicos
    print(df_agricola[col].nunique())#conteo de valores unicos
    print()

# %%
df_agricola[df_agricola.variedad.isna()]
# Out:
#        semana fecha_inicio                            region  \
# 15          1   2019-12-30      región_de_arica_y_parinacota
# 16          1   2019-12-30      región_de_arica_y_parinacota
# 19          1   2019-12-30      región_de_arica_y_parinacota
# 20          1   2019-12-30      región_de_arica_y_parinacota
# 30          1   2019-12-30      región_de_arica_y_parinacota
# ...       ...          ...                               ...
# 159253     27   2026-06-29  región_metropolitana_de_santiago
# 159254     27   2026-06-29  región_metropolitana_de_santiago
# 159255     27   2026-06-29  región_metropolitana_de_santiago
# 159259     27   2026-06-29  región_metropolitana_de_santiago
# 159263     27   2026-06-29  región_metropolitana_de_santiago
#
#          tipo_punto_monitoreo  producto variedad  calidad  unidad  \
# 15          mercado_minorista  frutilla      NaN  primera  $/kilo
# 16          mercado_minorista  frutilla      NaN  segunda  $/kilo
# 19          mercado_minorista     mango      NaN  primera  $/kilo
# 20          mercado_minorista     mango      NaN  segunda  $/kilo
# 30          mercado_minorista   plátano      NaN  primera  $/kilo
# ...                       ...       ...      ...      ...     ...
# 159253           supermercado   plátano      NaN  primera  $/kilo
# 159254           supermercado      tuna      NaN  primera  $/kilo
# 159255           supermercado      tuna      NaN  segunda  $/kilo
# 159259  supermercado_en_línea     mango      NaN  primera  $/kilo
# 159263  supermercado_en_línea   plátano      NaN  primera  $/kilo
#
#         precio_minimo  precio_maximo  precio_promedio  anio  mes
# 15             3500.0         4000.0           3750.0  2020   12
# 16             2500.0         3000.0           2750.0  2020   12
# 19             1200.0         1300.0           1250.0  2020   12
# 20             1000.0         1000.0           1000.0  2020   12
# 30              500.0          600.0            550.0  2020   12
# ...               ...            ...              ...   ...  ...
# 159253          990.0         1690.0           1411.0  2026    6
# 159254         3290.0         3890.0           3423.0  2026    6
# 159255         3290.0         3290.0           3290.0  2026    6
# 159259         2990.0         3010.0           2997.0  2026    6
# 159263         1450.0         1590.0           1520.0  2026    6
#
# [27073 rows x 13 columns]

# %% [markdown]
# ### Incluso tras limpiar se observan entradas con variedad nula
#
# #### esto podría ser perfectamente normal, ya que ciertos producto no se comercializan con una variedad asignada. si todas las frutas con campo variedad nulo presentan nulo para todas sus entradas esto puede ser el caso. Por otro lado, si una fruta; por ejemplo: limón, tiene algunos campos sin variedad y otros si, entonces esto es un error y se tendrá que tratar con estas entradas

# %%
for producto, variedades in df_agricola.groupby("producto")["variedad"].unique().items():
    print(f"{producto}: {list(variedades)}")
# Out:
# aceituna: ['amarga', 'negra', 'sevillana']
# arándano: ['blue']
# cereza: ['lapins', 'rainier', 'brooks', 'santina', 'early_burlat', 'sweet_heart', 'bing', 'van']
# chirimoya: [nan]
# ciruela: ['black_amber', 'larry_ann', 'fortuna', 'angeleno', 'sapphire']
# damasco: ['castle_brite', 'modesto']
# durazno: ['springcrest', 'carson', 'rich_lady', 'andross', 'elegant_lady', 'doctor_davis', 'september_sun', 'phillips_cling', 'september_sweet', 'florida_king', 'springtime', 'flavor_crest', 'manon', 'royal_glory', 'early_majestic', 'polar_king', 'artic_snow', 'white_lady', 'conservero']
# frambuesa: [nan]
# frutilla: [nan]
# kiwi: ['hayward']
# limón: ['plateado', 'amarillo']
# mandarina: ['clementina', 'clemenuless', 'murcott']
# mango: [nan]
# manzana: ['fuji_royal', 'granny_smith', 'royal_gala', 'pink_lady']
# naranja: ['valencia', 'fukumoto', 'navel_late', 'lane_late', 'new_hall', 'valenciana']
# nectarín: ['early_john', 'super_queen', 'june_pearl', 'venus', 'artic_sprite', 'august_red', 'artic_snow', 'artic_star', 'early_glo', 'nectar_crest', 'ruby_diamond', 'artic_pride', 'super_august', 'spring_bright', 'artic_mist', 'red_diamond']
# palta: ['hass', 'edranol']
# pera: ["packham's_triumph", 'bartlett_de_verano', 'winter_nelis']
# plátano: [nan]
# tuna: [nan]
# uva: ['flame_seedless', 'superior_seedless', 'red_globe', 'thompson_seedless']

# %% [markdown]
# ## Conclusiones del experimento anterior:
#
# ### Las frutas cuya variedad es nula tienen este valor para todas sus entradas. Por ende no corresponde un error por parte de la entidad que facilitó los datos ni durante el proceso de preparación. Dado que las columnas producto y variedad cumplen conjuntamente la función de identificar el producto, se combinarán en una única variable para reducir la cantidad de valores nulos sin perder información
#
# #### Como ya se mencionó antes, no todos los productos se comercializan o registran diferenciando variedades, por lo que la ausencia de este atributo es esperable para ciertos casos.

# %%
#Formato "producto" + "_" + "variedad"
df_agricola["producto_variedad"] = (
    df_agricola["producto"] +
    df_agricola["variedad"].fillna("").radd("_").where(
        df_agricola["variedad"].notna(), ""
    )
)

#Nota: "texto" + nan = nan. sin fillna("") para asegurarse que almenos haya una cadena vacia con la que sumar puede dar el resultado anterior.

# %%
df_agricola
# Out:
#        semana fecha_inicio                            region  \
# 0           1   2019-12-30      región_de_arica_y_parinacota
# 1           1   2019-12-30      región_de_arica_y_parinacota
# 2           1   2019-12-30      región_de_arica_y_parinacota
# 3           1   2019-12-30      región_de_arica_y_parinacota
# 4           1   2019-12-30      región_de_arica_y_parinacota
# ...       ...          ...                               ...
# 159259     27   2026-06-29  región_metropolitana_de_santiago
# 159260     27   2026-06-29  región_metropolitana_de_santiago
# 159261     27   2026-06-29  región_metropolitana_de_santiago
# 159262     27   2026-06-29  región_metropolitana_de_santiago
# 159263     27   2026-06-29  región_metropolitana_de_santiago
#
#          tipo_punto_monitoreo  producto           variedad  calidad  unidad  \
# 0           mercado_minorista  aceituna             amarga    extra  $/kilo
# 1           mercado_minorista  aceituna             amarga  primera  $/kilo
# 2           mercado_minorista  aceituna             amarga  segunda  $/kilo
# 3           mercado_minorista  aceituna             amarga  tercera  $/kilo
# 4           mercado_minorista  aceituna              negra    extra  $/kilo
# ...                       ...       ...                ...      ...     ...
# 159259  supermercado_en_línea     mango                NaN  primera  $/kilo
# 159260  supermercado_en_línea   manzana       granny_smith  primera  $/kilo
# 159261  supermercado_en_línea     palta               hass  primera  $/kilo
# 159262  supermercado_en_línea      pera  packham's_triumph  primera  $/kilo
# 159263  supermercado_en_línea   plátano                NaN  primera  $/kilo
#
#         precio_minimo  precio_maximo  precio_promedio  anio  mes  \
# 0              3500.0         4000.0           3750.0  2020   12
# 1              3000.0         3500.0           3250.0  2020   12
# 2              2500.0         3000.0           2750.0  2020   12
# 3              2000.0         2500.0           2250.0  2020   12
# 4              3000.0         3500.0           3250.0  2020   12
# ...               ...            ...              ...   ...  ...
# 159259         2990.0         3010.0           2997.0  2026    6
# 159260         1990.0         2590.0           2415.0  2026    6
# 159261         6290.0         6490.0           6423.0  2026    6
# 159262         2150.0         2190.0           2177.0  2026    6
# 159263         1450.0         1590.0           1520.0  2026    6
#
#              producto_variedad
# 0              aceituna_amarga
# 1              aceituna_amarga
# 2              aceituna_amarga
# 3              aceituna_amarga
# 4               aceituna_negra
# ...                        ...
# 159259                   mango
# 159260    manzana_granny_smith
# 159261              palta_hass
# 159262  pera_packham's_triumph
# 159263                 plátano
#
# [159264 rows x 14 columns]

# %%
#Creamos el archivo nuevo, con toda la data y limpio
#Opto CSV por sobre xslx para que sea visualmente diferenciable incluso sin leer el nombre del archivo.
df_agricola.to_csv("./Data/precio-consumidor-clean.csv", index=False)

# %% [markdown]
# # Data meteorológica
#
# ## Preparación de los datos meteorológicos
#
# La información meteorológica original corresponde a observaciones diarias.
#
# Como el dataset agrícola se encuentra organizado semanalmente, es necesario transformar ambas fuentes a la misma granularidad temporal antes de integrarlas.
#
# **Más sobre el dataset puede encontrarse en el notebook DataCollection en el cual se recolectó la data**

# %%
df_meteo = pd.read_csv("./Data/Meteo.csv")

# %%
df_meteo
# Out:
#              time  temperature_2m_mean  temperature_2m_max  \
# 0      2020-01-01                 23.0                26.2
# 1      2020-01-02                 23.0                26.1
# 2      2020-01-03                 23.6                27.8
# 3      2020-01-04                 23.5                26.4
# 4      2020-01-05                 23.9                27.4
# ...           ...                  ...                 ...
# 37067  2023-12-28                  6.7                10.2
# 37068  2023-12-29                  8.7                11.1
# 37069  2023-12-30                 10.8                15.1
# 37070  2023-12-31                 10.7                13.6
# 37071  2024-01-01                 14.3                18.1
#
#        temperature_2m_min  precipitation_sum  \
# 0                    20.9                0.0
# 1                    20.4                2.1
# 2                    20.4                1.0
# 3                    20.5                0.0
# 4                    21.3                0.0
# ...                   ...                ...
# 37067                 4.2                1.7
# 37068                 4.7                2.3
# 37069                 7.7                0.0
# 37070                 8.3                1.0
# 37071                 9.5                0.2
#
#                                                region
# 0                        Región de Arica y Parinacota
# 1                        Región de Arica y Parinacota
# 2                        Región de Arica y Parinacota
# 3                        Región de Arica y Parinacota
# 4                        Región de Arica y Parinacota
# ...                                               ...
# 37067  Región de Magallanes y de la Antártica Chilena
# 37068  Región de Magallanes y de la Antártica Chilena
# 37069  Región de Magallanes y de la Antártica Chilena
# 37070  Región de Magallanes y de la Antártica Chilena
# 37071  Región de Magallanes y de la Antártica Chilena
#
# [37072 rows x 6 columns]

# %% [markdown]
# ### Agregación semanal
#
# Las variables meteorológicas se agrupan utilizando el calendario ISO (año y semana ISO), calculando el promedio semanal para cada región.
#
# Este criterio garantiza la compatibilidad temporal con el dataset agrícola.

# %%
df_meteo["time"] = pd.to_datetime(df_meteo["time"])

iso = df_meteo["time"].dt.isocalendar() # necesito usar ISO por que los datos agrícolas están por semana en este formato.
#ej: 1ra semana de 2020 parte del 30 de diciembre de 2019.

df_meteo["anio"] = iso.year
df_meteo["semana"] = iso.week

# %%
#Pasamos los datos diarios a semanales. las estadisticas pasarían de valores medios diarios a medias semanales
df_meteo_semanal = (
    df_meteo
    .groupby(["region", "anio", "semana"])
    .mean(numeric_only=True)
    .reset_index()
)

# %%
df_meteo_semanal
# Out:
#                     region  anio  semana  temperature_2m_mean  \
# 0     Región Metropolitana  2020       1            21.520000
# 1     Región Metropolitana  2020       2            21.400000
# 2     Región Metropolitana  2020       3            23.957143
# 3     Región Metropolitana  2020       4            23.714286
# 4     Región Metropolitana  2020       5            23.628571
# ...                    ...   ...     ...                  ...
# 5305      Región del Maule  2026      23            10.928571
# 5306      Región del Maule  2026      24             9.714286
# 5307      Región del Maule  2026      25             8.828571
# 5308      Región del Maule  2026      26             6.542857
# 5309      Región del Maule  2026      27             4.933333
#
#       temperature_2m_max  temperature_2m_min  precipitation_sum
# 0              28.900000           15.480000           0.000000
# 1              29.542857           14.700000           0.000000
# 2              32.400000           17.514286           0.000000
# 3              31.771429           17.385714           0.000000
# 4              31.585714           17.600000           0.000000
# ...                  ...                 ...                ...
# 5305           14.557143            8.242857           0.585714
# 5306           13.028571            7.528571           3.442857
# 5307           14.057143            5.200000           1.100000
# 5308           12.585714            2.457143           0.042857
# 5309           11.033333            1.266667           0.000000
#
# [5310 rows x 7 columns]

# %%
categorical_cols = list(df_meteo_semanal.dtypes[df_meteo_semanal.dtypes == 'str'].index) # solo region...

# %%
formatCategorical(df_meteo_semanal, categorical_cols)
formatColNames(df_meteo_semanal)

# %%
df_meteo_semanal
# Out:
#                     region  anio  semana  temperature_2m_mean  \
# 0     región_metropolitana  2020       1            21.520000
# 1     región_metropolitana  2020       2            21.400000
# 2     región_metropolitana  2020       3            23.957143
# 3     región_metropolitana  2020       4            23.714286
# 4     región_metropolitana  2020       5            23.628571
# ...                    ...   ...     ...                  ...
# 5305      región_del_maule  2026      23            10.928571
# 5306      región_del_maule  2026      24             9.714286
# 5307      región_del_maule  2026      25             8.828571
# 5308      región_del_maule  2026      26             6.542857
# 5309      región_del_maule  2026      27             4.933333
#
#       temperature_2m_max  temperature_2m_min  precipitation_sum
# 0              28.900000           15.480000           0.000000
# 1              29.542857           14.700000           0.000000
# 2              32.400000           17.514286           0.000000
# 3              31.771429           17.385714           0.000000
# 4              31.585714           17.600000           0.000000
# ...                  ...                 ...                ...
# 5305           14.557143            8.242857           0.585714
# 5306           13.028571            7.528571           3.442857
# 5307           14.057143            5.200000           1.100000
# 5308           12.585714            2.457143           0.042857
# 5309           11.033333            1.266667           0.000000
#
# [5310 rows x 7 columns]

# %% [raw]
# Recordatorio: dropear semana luego de hacer merge

# %%
print(df_agricola[["region", "anio", "semana"]].dtypes)
print(df_meteo_semanal[["region", "anio", "semana"]].dtypes)
# Out:
# region       str
# anio      UInt32
# semana    object
# dtype: object
# region       str
# anio      UInt32
# semana    UInt32
# dtype: object

# %% [markdown]
# ## Los datos agrícolas se limitan a 9 regiones :
#
#         ['región_de_arica_y_parinacota',
#          'región_de_coquimbo',
#          'región_de_la_araucanía',
#          'región_de_los_lagos',
#          'región_de_ñuble',
#          'región_de_valparaíso',
#          'región_del_biobío',
#          'región_del_maule',
#          'región_metropolitana']
# #### Los datos meteorológicos son para las 16 regiones. Hay que reducirlo y corregir discrepancias de nombres antes de realizar el Merge

# %%
list(df_agricola.region.unique())
# Out:
# ['región_de_arica_y_parinacota',
#  'región_de_coquimbo',
#  'región_de_la_araucanía',
#  'región_de_los_lagos',
#  'región_de_ñuble',
#  'región_de_valparaíso',
#  'región_del_biobío',
#  'región_del_maule',
#  'región_metropolitana_de_santiago']

# %%
df_meteo_semanal.region.unique()
# Out:
# <StringArray>
# [                            'región_metropolitana',
#                             'región_de_antofagasta',
#                      'región_de_arica_y_parinacota',
#                                 'región_de_atacama',
#                                   'región_de_aysén',
#                                'región_de_coquimbo',
#                            'región_de_la_araucanía',
#                               'región_de_los_lagos',
#                                'región_de_los_ríos',
#    'región_de_magallanes_y_de_la_antártica_chilena',
#                                'región_de_tarapacá',
#                              'región_de_valparaíso',
#                                   'región_de_ñuble',
#                                 'región_del_biobío',
#  'región_del_libertador_general_bernardo_o'higgins',
#                                  'región_del_maule']
# Length: 16, dtype: str

# %%
#Diferencia en como se encuentra escrito la RM en ambos dataset
df_agricola.loc[df_agricola["region"] == "región_metropolitana_de_santiago", "region"] = "región_metropolitana"

# %% [markdown]
# ### Nos quedamos solo con la data meteorológica de cuyas regiones tenemos información en nuestro dataset agrícola

# %%
regiones_agricolas = df_agricola["region"].unique()

df_meteo_semanal = df_meteo_semanal[
    df_meteo_semanal["region"].isin(regiones_agricolas)
]

# %%
df_meteo_semanal.region.unique()# cambios correctos
# Out:
# <StringArray>
# [        'región_metropolitana', 'región_de_arica_y_parinacota',
#            'región_de_coquimbo',       'región_de_la_araucanía',
#           'región_de_los_lagos',         'región_de_valparaíso',
#               'región_de_ñuble',            'región_del_biobío',
#              'región_del_maule']
# Length: 9, dtype: str

# %% [markdown]
# ### Integración de fuentes
#
# Finalmente, los datos agrícolas y meteorológicos se integran utilizando como claves:
#
# - Región
# - Año ISO
# - Semana ISO

# %%
df_final = df_agricola.merge(
    df_meteo_semanal,
    on=["region", "anio", "semana"],
    how="left"
)

# %%
#un merge bien efectuad debería dar 0 na
df_final[df_final["temperature_2m_mean"].isna()]
# Out:
# Empty DataFrame
# Columns: [semana, fecha_inicio, region, tipo_punto_monitoreo, producto, variedad, calidad, unidad, precio_minimo, precio_maximo, precio_promedio, anio, mes, producto_variedad, temperature_2m_mean, temperature_2m_max, temperature_2m_min, precipitation_sum]
# Index: []

# %%
#Comprobamos la eficacia del merge revisando si existen combinatorias que no fueron aplicadas/ darían NA
claves_agri = set(zip(df_agricola["region"],
                      df_agricola["anio"],
                      df_agricola["semana"]))

claves_meteo = set(zip(df_meteo_semanal["region"],
                   df_meteo_semanal["anio"],
                       df_meteo_semanal["semana"]))

faltantes = claves_agri - claves_meteo

len(faltantes)
# Out:
# 0

# %%
df_final.head()
# Out:
#   semana fecha_inicio                        region tipo_punto_monitoreo  \
# 0      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 1      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 2      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 3      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 4      1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
#
#    producto variedad  calidad  unidad  precio_minimo  precio_maximo  \
# 0  aceituna   amarga    extra  $/kilo         3500.0         4000.0
# 1  aceituna   amarga  primera  $/kilo         3000.0         3500.0
# 2  aceituna   amarga  segunda  $/kilo         2500.0         3000.0
# 3  aceituna   amarga  tercera  $/kilo         2000.0         2500.0
# 4  aceituna    negra    extra  $/kilo         3000.0         3500.0
#
#    precio_promedio  anio  mes producto_variedad  temperature_2m_mean  \
# 0           3750.0  2020   12   aceituna_amarga                 23.4
# 1           3250.0  2020   12   aceituna_amarga                 23.4
# 2           2750.0  2020   12   aceituna_amarga                 23.4
# 3           2250.0  2020   12   aceituna_amarga                 23.4
# 4           3250.0  2020   12    aceituna_negra                 23.4
#
#    temperature_2m_max  temperature_2m_min  precipitation_sum
# 0               26.78                20.7               0.62
# 1               26.78                20.7               0.62
# 2               26.78                20.7               0.62
# 3               26.78                20.7               0.62
# 4               26.78                20.7               0.62

# %% [markdown]
# ## Dataset final
#
# El resultado corresponde a un dataset consolidado que contiene:
#
# - información agrícola;
# - variables meteorológicas agregadas semanalmente;
# - fechas normalizadas;
# - variables categóricas y nombres de columnas estandarizadas.
#
# Este archivo constituye la base utilizada en las etapas posteriores de análisis exploratorio, entrenamiento y evaluación de modelos.

# %%
df_final.to_csv("./Data/processed_agricultural_prices.csv", index=False)
