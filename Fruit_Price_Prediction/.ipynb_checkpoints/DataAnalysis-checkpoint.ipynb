# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Análisis Exploratorio de Datos

# %%
df = pd.read_csv("./Data/processed_agricultural_prices.csv")

# %%
df.head()
# Out:
#    semana fecha_inicio                        region tipo_punto_monitoreo  \
# 0       1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 1       1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 2       1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 3       1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
# 4       1   2019-12-30  región_de_arica_y_parinacota    mercado_minorista
#
#    producto variedad  calidad  unidad  precio_minimo  precio_maximo  \
# 0  aceituna   amarga    extra  $/kilo         3500.0         4000.0
# 1  aceituna   amarga  primera  $/kilo         3000.0         3500.0
# 2  aceituna   amarga  segunda  $/kilo         2500.0         3000.0
# 3  aceituna   amarga  tercera  $/kilo         2000.0         2500.0
# 4  aceituna    negra    extra  $/kilo         3000.0         3500.0
#
#    precio_promedio  anio  mes  temperature_2m_mean  temperature_2m_max  \
# 0           3750.0  2020   12                 23.4               26.78
# 1           3250.0  2020   12                 23.4               26.78
# 2           2750.0  2020   12                 23.4               26.78
# 3           2250.0  2020   12                 23.4               26.78
# 4           3250.0  2020   12                 23.4               26.78
#
#    temperature_2m_min  precipitation_sum
# 0                20.7               0.62
# 1                20.7               0.62
# 2                20.7               0.62
# 3                20.7               0.62
# 4                20.7               0.62

# %%
# %matplotlib inline

# %% [markdown]
# ### Distribución de precio_promedio

# %%
sns.histplot(df.precio_promedio,bins=50)
# Out:
# <Axes: xlabel='precio_promedio', ylabel='Count'>

# %% [markdown]
# ### Al reducir el rango máximo del eje x se puede apreciar mejor la cola que los datos generan

# %%
sns.histplot(df.precio_promedio[df.precio_promedio<=8000], bins=50)
# Out:
# <Axes: xlabel='precio_promedio', ylabel='Count'>

# %%
df[df.variedad == 'sin_especificar']
# Out:
#         semana fecha_inicio                        region  \
# 15           1   2019-12-30  región_de_arica_y_parinacota
# 16           1   2019-12-30  región_de_arica_y_parinacota
# 17           1   2019-12-30  región_de_arica_y_parinacota
# 18           1   2019-12-30  región_de_arica_y_parinacota
# 19           1   2019-12-30  región_de_arica_y_parinacota
# ...        ...          ...                           ...
# 159254      27   2026-06-29          región_metropolitana
# 159255      27   2026-06-29          región_metropolitana
# 159257      27   2026-06-29          región_metropolitana
# 159259      27   2026-06-29          región_metropolitana
# 159263      27   2026-06-29          región_metropolitana
#
#          tipo_punto_monitoreo  producto         variedad      calidad  unidad  \
# 15          mercado_minorista  frutilla  sin_especificar      primera  $/kilo
# 16          mercado_minorista  frutilla  sin_especificar      segunda  $/kilo
# 17          mercado_minorista     limón  sin_especificar  1a_plateado  $/kilo
# 18          mercado_minorista     limón  sin_especificar  2a_amarillo  $/kilo
# 19          mercado_minorista     mango  sin_especificar      primera  $/kilo
# ...                       ...       ...              ...          ...     ...
# 159254           supermercado      tuna  sin_especificar      primera  $/kilo
# 159255           supermercado      tuna  sin_especificar      segunda  $/kilo
# 159257  supermercado_en_línea     limón  sin_especificar  1a_amarillo  $/kilo
# 159259  supermercado_en_línea     mango  sin_especificar      primera  $/kilo
# 159263  supermercado_en_línea   plátano  sin_especificar      primera  $/kilo
#
#         precio_minimo  precio_maximo  precio_promedio  anio  mes  \
# 15             3500.0         4000.0           3750.0  2020   12
# 16             2500.0         3000.0           2750.0  2020   12
# 17              900.0         1000.0            950.0  2020   12
# 18              850.0          900.0            875.0  2020   12
# 19             1200.0         1300.0           1250.0  2020   12
# ...               ...            ...              ...   ...  ...
# 159254         3290.0         3890.0           3423.0  2026    6
# 159255         3290.0         3290.0           3290.0  2026    6
# 159257         1390.0         1590.0           1490.0  2026    6
# 159259         2990.0         3010.0           2997.0  2026    6
# 159263         1450.0         1590.0           1520.0  2026    6
#
#         temperature_2m_mean  temperature_2m_max  temperature_2m_min  \
# 15                23.400000           26.780000                20.7
# 16                23.400000           26.780000                20.7
# 17                23.400000           26.780000                20.7
# 18                23.400000           26.780000                20.7
# 19                23.400000           26.780000                20.7
# ...                     ...                 ...                 ...
# 159254             8.333333           14.533333                 4.0
# 159255             8.333333           14.533333                 4.0
# 159257             8.333333           14.533333                 4.0
# 159259             8.333333           14.533333                 4.0
# 159263             8.333333           14.533333                 4.0
#
#         precipitation_sum
# 15                   0.62
# 16                   0.62
# 17                   0.62
# 18                   0.62
# 19                   0.62
# ...                   ...
# 159254               0.00
# 159255               0.00
# 159257               0.00
# 159259               0.00
# 159263               0.00
#
# [47395 rows x 17 columns]

# %%
df[df.precio_promedio>=6000]
# Out:
#         semana fecha_inicio                        region  \
# 347          2   2020-01-06  región_de_arica_y_parinacota
# 383          2   2020-01-06  región_de_arica_y_parinacota
# 411          2   2020-01-06  región_de_arica_y_parinacota
# 655          2   2020-01-06          región_de_valparaíso
# 660          2   2020-01-06          región_de_valparaíso
# ...        ...          ...                           ...
# 159099      27   2026-06-29          región_de_valparaíso
# 159111      27   2026-06-29          región_de_valparaíso
# 159226      27   2026-06-29          región_metropolitana
# 159227      27   2026-06-29          región_metropolitana
# 159261      27   2026-06-29          región_metropolitana
#
#          tipo_punto_monitoreo         producto         variedad  calidad  \
# 347               feria_libre  arándano_(blue)  sin_especificar  segunda
# 383         mercado_minorista  arándano_(blue)  sin_especificar  segunda
# 411              supermercado         frutilla  sin_especificar  primera
# 655              supermercado  arándano_(blue)  sin_especificar  primera
# 660              supermercado        frambuesa  sin_especificar  primera
# ...                       ...              ...              ...      ...
# 159099           supermercado         frutilla  sin_especificar  primera
# 159111           supermercado            palta             hass  primera
# 159226           supermercado  arándano_(blue)  sin_especificar  primera
# 159227           supermercado         frutilla  sin_especificar  primera
# 159261  supermercado_en_línea            palta             hass  primera
#
#         unidad  precio_minimo  precio_maximo  precio_promedio  anio  mes  \
# 347     $/kilo        10000.0        10000.0          10000.0  2020    1
# 383     $/kilo        10000.0        10000.0          10000.0  2020    1
# 411     $/kilo         6633.0         6633.0           6633.0  2020    1
# 655     $/kilo         4290.0         9300.0           7082.0  2020    1
# 660     $/kilo         6990.0         7990.0           7490.0  2020    1
# ...        ...            ...            ...              ...   ...  ...
# 159099  $/kilo         9967.0         9967.0           9967.0  2026    6
# 159111  $/kilo         4990.0         6490.0           6090.0  2026    6
# 159226  $/kilo        13633.0        19120.0          16377.0  2026    6
# 159227  $/kilo         8633.0         8633.0           8633.0  2026    6
# 159261  $/kilo         6290.0         6490.0           6423.0  2026    6
#
#         temperature_2m_mean  temperature_2m_max  temperature_2m_min  \
# 347               23.471429           27.142857           20.585714
# 383               23.471429           27.142857           20.585714
# 411               23.471429           27.142857           20.585714
# 655               17.071429           20.657143           13.642857
# 660               17.071429           20.657143           13.642857
# ...                     ...                 ...                 ...
# 159099            10.166667           13.733333            7.500000
# 159111            10.166667           13.733333            7.500000
# 159226             8.333333           14.533333            4.000000
# 159227             8.333333           14.533333            4.000000
# 159261             8.333333           14.533333            4.000000
#
#         precipitation_sum
# 347              0.028571
# 383              0.028571
# 411              0.028571
# 655              0.000000
# 660              0.000000
# ...                   ...
# 159099           0.000000
# 159111           0.000000
# 159226           0.000000
# 159227           0.000000
# 159261           0.000000
#
# [3883 rows x 17 columns]
